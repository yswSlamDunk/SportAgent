# %%
import os
import json

from langchain_core.documents import Document
from langchain_openai.embeddings import OpenAIEmbeddings

# %%
path = '../data/document/역도/역도 훈련프로그램 구성 및 지도안_dataset.json'

with open(path, 'r', encoding='utf-8') as f:
    state = json.load(f)

# %%
documents = []

for document in state['documents']:
    metadata = document['metadata']
    
    filepath = metadata['filepath']
    pages = metadata['page']
    heading1 = metadata['heading']['heading1']
    heading2 = metadata['heading']['heading2']
    heading3 = metadata['heading']['heading3']
    heading4 = metadata['heading']['heading4']
    heading5 = metadata['heading']['heading5']
    heading = metadata['heading']['default']
    index = metadata['index']

    content = document['content']

# %%
state['documents']
# Out:
# [{'meta': {'filepath': '../data/document/역도/역도 훈련프로그램 구성 및 지도안_edited.json',
#    'heading': {'heading1': 'Ⅴ.역도 훈련프로그램 구성 및 지도안',
#     'heading2': '1. 훈련프로그램의 구성 원리',
#     'heading3': None,
#     'heading4': None,
#     'heading5': None,
#     'default': None},
#    'index': 0,
#    'summary': '- 역도 훈련 프로그램은 안전하고 효과적으로 설계되어야 한다.\n- 훈련 프로그램 구성은 개인의 특수성, 과부하, 점진성에 기반한다.\n- 훈련의 원리에 입각하여 구성된다.',
#    'pages': [1]},
#   'content': [{'category': 'paragraph',
#     'information': '역도 훈련프로그램의 구성은 트레이닝의 원리에 입각하여 안전하고 효과적인 훈\n련 프로그램을 설계하여 선수 개개인의 특수성, 과부하, 점진성의 일반적인 훈련원\n칙에 근거한다.'}]},
#  {'meta': {'filepath': '../data/document/역도/역도 훈련프로그램 구성 및 지도안_edited.json',
#    'heading': {'heading1': 'Ⅴ.역도 훈련프로그램 구성 및 지도안',
#     'heading2': '1. 훈련프로그램의 구성 원리',
#     'heading3': '가. 일반적인 훈련원칙(general training principle)',
#     'heading4': '1) 특수성(specificity)',
#     'heading5': None,
#     'default': None},
#    'index': 1,
# ...

# %%
documents = []

for document in state['documents']:
    metadata = document['metadata']
    
    filepath = metadata['filepath']
    pages = metadata['page']
    heading1 = metadata['heading']['heading1']
    heading2 = metadata['heading']['heading2']
    heading3 = metadata['heading']['heading3']
    heading4 = metadata['heading']['heading4']
    heading5 = metadata['heading']['heading5']
    heading = metadata['heading']['default']
    index = metadata['index']

    content = document['content']
# Out:
# [{'meta': {'filepath': '../data/document/역도/역도 훈련프로그램 구성 및 지도안_edited.json',
#    'heading': {'heading1': 'Ⅴ.역도 훈련프로그램 구성 및 지도안',
#     'heading2': '1. 훈련프로그램의 구성 원리',
#     'heading3': None,
#     'heading4': None,
#     'heading5': None,
#     'default': None},
#    'index': 0,
#    'summary': '- 역도 훈련 프로그램은 안전하고 효과적으로 설계되어야 한다.\n- 훈련 프로그램 구성은 개인의 특수성, 과부하, 점진성에 기반한다.\n- 훈련의 원리에 입각하여 구성된다.',
#    'pages': [1]},
#   'content': [{'category': 'paragraph',
#     'information': '역도 훈련프로그램의 구성은 트레이닝의 원리에 입각하여 안전하고 효과적인 훈\n련 프로그램을 설계하여 선수 개개인의 특수성, 과부하, 점진성의 일반적인 훈련원\n칙에 근거한다.'}]},
#  {'meta': {'filepath': '../data/document/역도/역도 훈련프로그램 구성 및 지도안_edited.json',
#    'heading': {'heading1': 'Ⅴ.역도 훈련프로그램 구성 및 지도안',
#     'heading2': '1. 훈련프로그램의 구성 원리',
#     'heading3': '가. 일반적인 훈련원칙(general training principle)',
#     'heading4': '1) 특수성(specificity)',
#     'heading5': None,
#     'default': None},
#    'index': 1,
# ...
